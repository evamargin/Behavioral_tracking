# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Manually input or extract data
data = [
    ("2024-12-23 15:53:38", 4),
    ("2024-12-24 15:46:20", 5),
    ("2024-12-25 21:10:08", 26),
    ("2024-12-26 16:12:58", 17),
    ("2024-12-27 16:39:11", 10),
    ("2024-12-27 19:17:06", 12),
    ("2024-12-28 22:17:40", 7),
    ("2024-12-29 15:34:57", 9),
    ("2024-12-30 17:06:20", 9),
    ("2024-12-30 19:54:20", 6),
    ("2025-01-02 17:33:00", 3),
    ("2025-01-03 18:38:49", 13),
    ("2025-01-04 16:13:54", 10),
    ("2025-01-05 14:26:50", 15),
    ("2025-01-06 17:27:30", 23),
    ("2025-01-07 21:01:33", 14),
    ("2025-01-08 18:58:42", 22),
    ("2025-01-09 22:01:49", 10),
    ("2025-01-10 15:28:58", 13),
    ("2025-01-12 18:19:54", 17),
    ("2025-01-13 20:20:19", 16),
    ("2025-01-14 22:13:21", 14),
    ("2025-01-15 21:01:50", 25),
    ("2025-01-19 19:47:10", 19),
    ("2025-01-20 20:09:28", 15),
    ("2025-01-21 18:17:50", 28),
    ("2025-01-22 19:46:36", 13),
    ("2025-01-23 18:24:56", 36),
    ("2025-01-24 16:18:28", 32),
    ("2025-01-29 20:26:58", 18),
    ("2025-02-02 17:14:55", 36),
    ("2025-02-03 13:52:54", 33),
]

# Convert to DataFrame
df = pd.DataFrame(data, columns=["Timestamp", "Value"])

# Convert timestamps to datetime format
df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# Plot the data
plt.figure(figsize=(6, 4))
plt.plot(df["Timestamp"], df["Value"], marker="o", linestyle="-")
plt.xlabel("Date")
plt.ylabel("nb of clusters")
plt.title("CA1")
plt.xticks(rotation=45)
plt.ylim(0,40)
plt.grid()

# Show the plot
plt.show()
